# %%
import os
import sys
import pandas as pd
import numpy as np
import datetime as dt
from datetime import date
from sqlalchemy import create_engine
from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from pyxlsb import open_workbook as open_xlsb

Environment="Local"
Batch =1

if Environment =="Local":
                        
                      PATH = "C:\Zeelan 2019\C&C model\\"
                      print("Local")
             
else:
     
                      PATH = "C:\DNA_C&C\Source_Files\\"
                      print("VM")


df= pd.read_excel (r"C:\\Zeelan 2019\\C&C model\Env_Details.xlsx",index=False)
print(df.shape)

today = date.today()
#today=date(2019,1,2)
print(today)

#Dstr = today.strftime("%d %b %y")
Dstr = "29 Nov 19"
#Dstr1 = today.strftime("%d") + "th" + " " + today.strftime("%b") + "'" +  today.strftime("%y")
Dstr1 = "29th Nov'19"
print(Dstr)


# to convert a dataframe to string 

Rname= df["RAS_Fname"].values.tolist()
Pname=df["Proj_Fname"].values.tolist()
Sname=df["SPS_Fname"].values.tolist()
Lname=df["LOV_Fname"].values.tolist()
#Pname=Pname + "  -as on"


print(Rname , Pname)
 
# Function to convert   
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1  
        
    print(listToString(Rname) ,"  , ", listToString(Pname) )


# Use current date to get a text file name.
def get_filename_datetime(P,Dstr):
    
    return listToString(P) + " " + str(Dstr) + ".xlsb"

# get a text file name with extension.
def get_filename(P):
    
    return listToString(P) + ".xlsx"
def get_filenameB(P):
    
    return listToString(P) + ".xlsb"

# Get full path for writing.
Rpath =   PATH + get_filename_datetime(Rname,Dstr1)
print("PATH", Rpath);
Ppath =   PATH + get_filename_datetime(Pname,Dstr)
print("PATH", Ppath);

Spath =   PATH + get_filename(Sname)
print("PATH", Spath);
Lpath =   PATH + get_filename(Lname)
print("PATH", Lpath);

#print(df)
# Out:
# Local
# (1, 7)
# 2019-12-03
# 29 Nov 19
# ['Apps n SI as of'] ['PI Master from SAP and PI -as on']
# PATH C:\Zeelan 2019\C&C model\Apps n SI as of 29th Nov'19.xlsb
# PATH C:\Zeelan 2019\C&C model\PI Master from SAP and PI -as on 29 Nov 19.xlsb
# PATH C:\Zeelan 2019\C&C model\SPS_chapter_update_v2.xlsx
# PATH C:\Zeelan 2019\C&C model\LOV.xlsx

# %%
import pandas
print('Pandas import succeeded!')
